# %% [markdown]
# <a href="https://colab.research.google.com/github/anikettttt123/greendestination-data-analytics/blob/main/unifiedinternship.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('/content/greendestination (1).csv')

# %%
df.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# ...

# %%
#counting the number of rows
row_count = len(df)
print(row_count)
# Out:
# 1470

# %% [markdown]
# ### ***Attrition Rate***

# %%
attrition_rate = (df['Attrition'] == 'Yes').mean() * 100
print("Attrition Rate:", attrition_rate, "%")
# Out:
# Attrition Rate: 16.122448979591837 %

# %% [markdown]
# ### ***Dependency of age on attrition***

# %%
plt.figure(figsize=(15, 9))
sns.countplot(x='Age', hue='Attrition', data=df)
plt.title('Attrition by Age')
plt.xlabel('Age')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# # From the above graph we can conclude that the attrition rate reduces as their age or experience increases in the organisation. Young ones or freshers have a higher rate of attrition as compared to experienced employees.

# %% [markdown]
# # ***Dependency of Years at company on attrition***

# %%
plt.figure(figsize=(15, 9))
sns.boxplot(x='Attrition', y='YearsAtCompany', data=df)
plt.title('Years at Company vs. Attrition')
plt.xlabel('Attrition')
plt.ylabel('Years at Company')
plt.show()

# %%
plt.figure(figsize=(15, 9))
sns.swarmplot(x='Attrition', y='YearsAtCompany', data=df)
plt.title('Years at Company vs. Attrition')
plt.xlabel('Attrition')
plt.ylabel('Years at Company')
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:3398: UserWarning: 28.3% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# ## From the above graph we can conclude that the attrition rate reduces as their years at company increases in the organisation. Young ones or freshers have a higher rate of attrition as compared to experienced employees.

# %% [markdown]
# ### ***Dependency of Monthly Income on attrition***

# %%
plt.figure(figsize=(10, 6))
sns.violinplot(x='Attrition', y='MonthlyIncome', data=df)
plt.title('Monthly Income vs. Attrition')
plt.xlabel('Attrition')
plt.ylabel('Monthly Income')
plt.show()

# %% [markdown]
# # From the above graph we can conclude that the attrition rate reduces as their monthly income increases in the organisation. Young ones or freshers have a higher rate of attrition as compared to experienced employees.
